# %%
from comparativos import comparativo_faturamento
from db import engine

# %%
df = comparativo_faturamento()
# Out:
# Conectando ao FTP 10.101.14.119:21...
# Conectado ao FTP com sucesso
# Diretório atual no FTP: Relatorios_inteligencia&Dados
# Encontrados 1 arquivo(s) no FTP com padrão faturamento_202602.xlsx
# Lido: faturamento_202602.xlsx -> 49367 linhas, 60 colunas
# doc_fat
# 2000127817     5880.60
# 2000127868     1553.71
# 2000127870      466.00
# 2000127883      798.60
# 2000127884      720.44
#                 ...
# 7400010812     3136.36
# 7400010813      188.48
# 7400010814     3990.94
# 7400010815     5416.76
# 7400010816    16787.45
# Name: valor_fat_liquido, Length: 3484, dtype: float64
